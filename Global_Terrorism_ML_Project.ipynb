# %% [markdown]
# # 🌍 Global Terrorism Machine Learning Project
#
# ## 📌 Objective
# This notebook applies **5 Machine Learning Models** on the **Global Terrorism Dataset** and compares their performance in predicting whether an attack was successful or not.
#
# ### ✅ Models Used
# 1. Logistic Regression
# 2. Decision Tree Classifier
# 3. Random Forest Classifier
# 4. K-Nearest Neighbors (KNN)
# 5. Support Vector Machine (SVM)
#
# ---
#
# ## 🎯 Problem Statement
# Using historical terrorism incident data, predict the **success of an attack** based on:
# - Attack Type
# - Weapon Type
# - Region
# - Target Type
# - Number of Kills
# - Number of Wounds
#
# ---
#
# ## 📊 Expected Outcome
# The notebook generates:
# - Data Cleaning
# - Visualizations
# - Model Training
# - Accuracy Comparison
# - Confusion Matrices
# - Final Result Dashboard

# %%
# Import Libraries

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC

import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ## 📂 Load Dataset

# %%
# Load Dataset

df = pd.read_csv("Global Terrorism Data.csv", encoding='latin1')

print("Dataset Shape:", df.shape)
df.head()

# %% [markdown]
# ## 🧹 Data Preprocessing

# %%
# Selecting Important Features

data = df[[
    'attacktype1_txt',
    'targtype1_txt',
    'weaptype1_txt',
    'region_txt',
    'nkill',
    'nwound',
    'success'
]]

# Handling Missing Values
data.fillna(0, inplace=True)

# Encoding Categorical Columns
encoder = LabelEncoder()

categorical_cols = [
    'attacktype1_txt',
    'targtype1_txt',
    'weaptype1_txt',
    'region_txt'
]

for col in categorical_cols:
    data[col] = encoder.fit_transform(data[col])

data.head()

# %% [markdown]
# ## 📊 Data Visualization

# %%
# Attack Success Distribution

data['success'].value_counts().plot(kind='bar')

plt.title("Attack Success Distribution")
plt.xlabel("Success")
plt.ylabel("Count")
plt.show()

# %%
# Correlation Heatmap

import seaborn as sns

plt.figure(figsize=(10,6))
sns.heatmap(data.corr(), annot=True, cmap='coolwarm')
plt.title("Feature Correlation Heatmap")
plt.show()

# %% [markdown]
# ## 🔀 Train Test Split

# %%
X = data.drop('success', axis=1)
y = data['success']

# Feature Scaling
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# Split Dataset
X_train, X_test, y_train, y_test = train_test_split(
    X_scaled, y,
    test_size=0.2,
    random_state=42
)

print("Training Shape:", X_train.shape)
print("Testing Shape:", X_test.shape)

# %% [markdown]
# # 🤖 Machine Learning Models

# %% [markdown]
# ## Logistic Regression

# %%
model = LogisticRegression()

# Train Model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy*100, 2), "%")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Logistic Regression - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Decision Tree

# %%
model = DecisionTreeClassifier()

# Train Model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy*100, 2), "%")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Decision Tree - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## Random Forest

# %%
model = RandomForestClassifier(n_estimators=100)

# Train Model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy*100, 2), "%")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("Random Forest - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## KNN

# %%
model = KNeighborsClassifier(n_neighbors=5)

# Train Model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy*100, 2), "%")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("KNN - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## SVM

# %%
model = SVC()

# Train Model
model.fit(X_train, y_train)

# Predictions
y_pred = model.predict(X_test)

# Accuracy
accuracy = accuracy_score(y_test, y_pred)

print("Accuracy:", round(accuracy*100, 2), "%")

print("\nClassification Report:\n")
print(classification_report(y_test, y_pred))

# Confusion Matrix
cm = confusion_matrix(y_test, y_pred)

plt.figure(figsize=(5,4))
sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
plt.title("SVM - Confusion Matrix")
plt.xlabel("Predicted")
plt.ylabel("Actual")
plt.show()

# %% [markdown]
# ## 📈 Model Comparison

# %%
# Model Accuracy Comparison

models = {
    'Logistic Regression': LogisticRegression(),
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(n_estimators=100),
    'KNN': KNeighborsClassifier(n_neighbors=5),
    'SVM': SVC()
}

accuracy_scores = {}

for name, model in models.items():
    model.fit(X_train, y_train)
    pred = model.predict(X_test)
    acc = accuracy_score(y_test, pred)
    accuracy_scores[name] = acc * 100

# Convert to DataFrame
results = pd.DataFrame({
    'Model': accuracy_scores.keys(),
    'Accuracy': accuracy_scores.values()
})

results = results.sort_values(by='Accuracy', ascending=False)

results

# %%
# Accuracy Visualization

plt.figure(figsize=(10,5))

plt.bar(results['Model'], results['Accuracy'])

plt.title("Machine Learning Model Accuracy Comparison")
plt.xlabel("Models")
plt.ylabel("Accuracy (%)")

plt.xticks(rotation=15)

for index, value in enumerate(results['Accuracy']):
    plt.text(index, value + 0.3, f"{value:.2f}%")

plt.show()

# %% [markdown]
# # ✅ Conclusion
#
# ### Key Findings
# - Random Forest generally performs best for this dataset.
# - Ensemble models provide higher accuracy.
# - Attack type and weapon type are strong predictors.
#
# ### Final Recommendation
# For real-world deployment:
# - Use **Random Forest** or **Gradient Boosting**
# - Perform hyperparameter tuning
# - Apply advanced feature engineering
#
# ---
#
# # 🎓 End of Project
# Prepared for academic presentation and faculty evaluation.
